# %%
# %pip install chatterbot
# Out:
# Collecting chatterbot
#   Downloading chatterbot-1.2.6-py3-none-any.whl.metadata (7.2 kB)
# Collecting mathparse<0.2,>=0.1 (from chatterbot)
#   Downloading mathparse-0.1.5-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil<2.10,>=2.9 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chatterbot) (2.9.0.post0)
# Collecting sqlalchemy<2.1,>=2.0 (from chatterbot)
#   Downloading sqlalchemy-2.0.40-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting spacy<3.9,>=3.8 (from chatterbot)
#   Downloading spacy-3.8.5-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: tqdm in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chatterbot) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<2.10,>=2.9->chatterbot) (1.16.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading murmurhash-1.0.12-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading cymem-2.0.11-cp311-cp311-win_amd64.whl.metadata (8.8 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading thinc-8.3.6-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading srsly-2.5.1-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading typer-0.15.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.32.3)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Collecting jinja2 (from spacy<3.9,>=3.8->chatterbot)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (24.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy<3.9,>=3.8->chatterbot)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot)
#   Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot) (4.13.2)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2024.6.2)
# Requirement already satisfied: greenlet>=1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy<2.1,>=2.0->chatterbot) (3.1.1)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy<3.9,>=3.8->chatterbot)
#   Downloading blis-1.3.0-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy<3.9,>=3.8->chatterbot)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.19.0 (from spacy<3.9,>=3.8->chatterbot)
#   Downloading numpy-2.2.5-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\roaming\python\python311\site-packages (from tqdm->chatterbot) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy<3.9,>=3.8->chatterbot)
#   Downloading cloudpathlib-0.21.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy<3.9,>=3.8->chatterbot)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.9,>=3.8->chatterbot)
#   Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.9,>=3.8->chatterbot)
#   Downloading marisa_trie-1.2.1-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\administrator\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy<3.9,>=3.8->chatterbot) (3.0.2)
# Downloading chatterbot-1.2.6-py3-none-any.whl (74 kB)
# Downloading mathparse-0.1.5-py3-none-any.whl (8.8 kB)
# Downloading spacy-3.8.5-cp311-cp311-win_amd64.whl (12.2 MB)
#    ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.2 MB 6.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.2 MB 5.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/12.2 MB 5.2 MB/s eta 0:00:02
#    -------------- ------------------------- 4.5/12.2 MB 5.2 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.2 MB 5.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.1/12.2 MB 5.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.2 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.7/12.2 MB 5.1 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.2 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.2 MB 4.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.7/12.2 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.2 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.2/12.2 MB 4.0 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp311-cp311-win_amd64.whl (39 kB)
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
# Downloading murmurhash-1.0.12-cp311-cp311-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl (122 kB)
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 2.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 2.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 2.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/2.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.6 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading sqlalchemy-2.0.40-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 4.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 3.7 MB/s eta 0:00:00
# Downloading srsly-2.5.1-cp311-cp311-win_amd64.whl (632 kB)
#    ---------------------------------------- 0.0/632.6 kB ? eta -:--:--
#    ---------------------------------------- 632.6/632.6 kB 3.9 MB/s eta 0:00:00
# Downloading thinc-8.3.6-cp311-cp311-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------------- ---------- 1.3/1.8 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.0 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp311-cp311-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.2 MB 6.3 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.2 MB 8.4 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.2 MB 8.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 7.1 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading numpy-2.2.5-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.9 MB 5.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.9 MB 8.7 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.9 MB 9.9 MB/s eta 0:00:01
#    --------------------- ------------------ 7.1/12.9 MB 10.1 MB/s eta 0:00:01
#    --------------------- ------------------ 7.1/12.9 MB 10.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/12.9 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 8.4/12.9 MB 5.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/12.9 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.7/12.9 MB 5.0 MB/s eta 0:00:01
#    ------------------------------ --------- 10.0/12.9 MB 4.7 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 4.5 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.9 MB 4.4 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.9 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.3/12.9 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.9 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/12.9 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 2.6 MB/s eta 0:00:00
# Downloading typer-0.15.3-py3-none-any.whl (45 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.21.0-py3-none-any.whl (52 kB)
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.4 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.4 MB 4.2 MB/s eta 0:00:01
#    --------------- ------------------------ 2.1/5.4 MB 4.7 MB/s eta 0:00:01
#    --------------- ------------------------ 2.1/5.4 MB 4.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.4 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.1/5.4 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 4.5/5.4 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 3.2 MB/s eta 0:00:00
# Downloading marisa_trie-1.2.1-cp311-cp311-win_amd64.whl (152 kB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl (38 kB)
# Installing collected packages: cymem, wrapt, wasabi, typing-inspection, sqlalchemy, spacy-loggers, spacy-legacy, shellingham, pydantic-core, numpy, murmurhash, markdown-it-py, marisa-trie, jinja2, cloudpathlib, catalogue, annotated-types, srsly, smart-open, rich, pydantic, preshed, language-data, blis, typer, langcodes, confection, weasel, thinc, spacy, mathparse, chatterbot
#
#    - --------------------------------------  1/32 [wrapt]
#    -- -------------------------------------  2/32 [wasabi]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ----- ----------------------------------  4/32 [sqlalchemy]
#    ------ ---------------------------------  5/32 [spacy-loggers]
#    ------- --------------------------------  6/32 [spacy-legacy]
#    -------- -------------------------------  7/32 [shellingham]
#    ---------- -----------------------------  8/32 [pydantic-core]
#   Attempting uninstall: numpy
#    ---------- -----------------------------  8/32 [pydantic-core]
#     Found existing installation: numpy 1.26.4
#    ---------- -----------------------------  8/32 [pydantic-core]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#     Uninstalling numpy-1.26.4:
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#       Successfully uninstalled numpy-1.26.4
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ----------- ----------------------------  9/32 [numpy]
#    ------------ --------------------------- 10/32 [murmurhash]
#    ------------- -------------------------- 11/32 [markdown-it-py]
#    ------------- -------------------------- 11/32 [markdown-it-py]
#    ------------- -------------------------- 11/32 [markdown-it-py]
#    ------------- -------------------------- 11/32 [markdown-it-py]
#    --------------- ------------------------ 12/32 [marisa-trie]
#    ---------------- ----------------------- 13/32 [jinja2]
#    ---------------- ----------------------- 13/32 [jinja2]
#    ---------------- ----------------------- 13/32 [jinja2]
#    ----------------- ---------------------- 14/32 [cloudpathlib]
#    ----------------- ---------------------- 14/32 [cloudpathlib]
#    ------------------ --------------------- 15/32 [catalogue]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    --------------------- ------------------ 17/32 [srsly]
#    ---------------------- ----------------- 18/32 [smart-open]
#    ---------------------- ----------------- 18/32 [smart-open]
#    ----------------------- ---------------- 19/32 [rich]
#    ----------------------- ---------------- 19/32 [rich]
#    ----------------------- ---------------- 19/32 [rich]
#    ----------------------- ---------------- 19/32 [rich]
#    ----------------------- ---------------- 19/32 [rich]
#    ----------------------- ---------------- 19/32 [rich]
#    ----------------------- ---------------- 19/32 [rich]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    ------------------------- -------------- 20/32 [pydantic]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    --------------------------- ------------ 22/32 [language-data]
#    ---------------------------- ----------- 23/32 [blis]
#    ---------------------------- ----------- 23/32 [blis]
#    ---------------------------- ----------- 23/32 [blis]
#    ------------------------------ --------- 24/32 [typer]
#    ------------------------------- -------- 25/32 [langcodes]
#    ------------------------------- -------- 25/32 [langcodes]
#    -------------------------------- ------- 26/32 [confection]
#    --------------------------------- ------ 27/32 [weasel]
#    --------------------------------- ------ 27/32 [weasel]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ----------------------------------- ---- 28/32 [thinc]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    ------------------------------------ --- 29/32 [spacy]
#    -------------------------------------- - 31/32 [chatterbot]
#    -------------------------------------- - 31/32 [chatterbot]
#    -------------------------------------- - 31/32 [chatterbot]
#    -------------------------------------- - 31/32 [chatterbot]
#    ---------------------------------------- 32/32 [chatterbot]
#
# Successfully installed annotated-types-0.7.0 blis-1.3.0 catalogue-2.0.10 chatterbot-1.2.6 cloudpathlib-0.21.0 confection-0.1.5 cymem-2.0.11 jinja2-3.1.6 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 mathparse-0.1.5 murmurhash-1.0.12 numpy-2.0.0 preshed-3.0.9 pydantic-2.11.4 pydantic-core-2.33.2 rich-14.0.0 shellingham-1.5.4 smart-open-7.1.0 spacy-3.8.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 sqlalchemy-2.0.40 srsly-2.5.1 thinc-8.3.6 typer-0.15.3 typing-inspection-0.4.0 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.2

# %%
# Import Libraries
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer

# Create the chatbot
studybot = ChatBot(
    'StudyBot',
    read_only=True,
    logic_adapters=[
        'chatterbot.logic.BestMatch'
    ]
)

# Training Data
conversation = [
    'Hi',
    'Hello! I am HealthBot. How can I assist you today?',
    'Hello',
    'Hi! Do you have a health-related question?','I have a headache',
    'You should rest, stay hydrated, and take a mild pain reliever if needed.',
    'What should I do if I have a fever?',
    'Drink plenty of fluids and rest. If the fever persists, please consult a doctor.',
    'I feel dizzy',
    'Sit down, breathe deeply, and drink water. If it continues, seek medical help.',
    'What should I eat for a cold?',
    'Warm fluids, soups, citrus fruits, and light meals help during a cold.',
    'How to stay healthy?',
    'Eat balanced meals, exercise regularly, stay hydrated, and get enough sleep.',
    'What should I do in case of a cut?',
    'Clean the wound with water, apply antiseptic, and cover it with a clean bandage.',
    'How much water should I drink daily?',
    'Generally, 2 to 3 liters per day is recommended, but it varies based on your activity.',
    'Thank you',
    'You’re welcome! Take care.',
    'Bye',
    'Goodbye! Stay healthy.'
]


# Train the chatbot
trainer = ListTrainer(studybot)
trainer.train(conversation)

# Chat Loop
print("HealthBot is ready! (Type 'exit' to end)")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("HealthBot: Goodbye! Stay Healthy.")
        break
    response = studybot.get_response(user_input)
    print(f"HealthBot: {response}")
# Out:
# List Trainer: 22it [00:00, 207.60it/s]
# HealthBot is ready! (Type 'exit' to end)
